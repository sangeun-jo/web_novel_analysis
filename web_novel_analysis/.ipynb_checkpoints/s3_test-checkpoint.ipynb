# %%
import os
import boto3
import pandas as pd
from io import StringIO
aws_id = 'AKIAIPHKZIJNFNELEDFA'
aws_secret = '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'
bucket_name = 'web-novel-db'
object_key = 'joara-tobe.csv'
client = boto3.client('s3',aws_access_key_id= aws_id, aws_secret_access_key=aws_secret)
csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
body = csv_obj['Body']
csv_string = body.read().decode('utf-8')
df = pd.read_csv(StringIO(csv_string))
print(df)
# Out:
#          date     genre                         title  \
# 0    20201220      [BL]              사모하여 그리워하다 <20편>
# 1    20201220  [로맨스판타지]          시한부 황제의 주치의입니다 <22편>
# 2    20201220      [BL]               슬로우 러브 어택 <22편>
# 3    20201220  [로맨스판타지]  내가 죽은 줄 알고 남편이 폭군이 되.. <32편>
# 4    20201220  [로맨스판타지]         미친 악당의 품으로 떨어졌다 <28편>
# ..        ...       ...                           ...
# 915  20210204     [패러디]              [원피스] 마르셀라 <25편>
# 916  20210204      [BL]                  빌런의 반란 <25편>
# 917  20210204     [패러디]          [하이큐] 내가 사는 이유 <67편>
# 918  20210204     [패러디]               [던만추] 인챈터 <41편>
# 919  20210204     [패러디]             [주술회전] 실화일까 <39편>
#
#                                                  intro
# 0    ‘......절경인지 가관인지...모르겠군.’\r\n\r\n청위소는 그런 침입자를 ...
# 1    주치의로서 황제를 살리지 못하고 죽기를 3회차.\r\n빌어먹을 황제놈을 구슬리다 지...
# 2    [아이돌물 / 연하공 미인공 짝사랑공 집착공 수한정다정공 / 연상수 다정수 능력수 ...
# 3    #부부재회 #여주한정울보남주# 기억상실증에 걸렸다가 10년만에 나았다. 그런데 착하...
# 4    19금 피폐물 소설에 빙의하자마자 하늘에서 떨어졌다.\r\n서부의 광룡, 살인귀라 ...
# ..                                                 ...
# 915  돈키호테 도플라밍고의 쌍둥이 형.\n게으르게 살고 싶어서 누구보다 열심히 살아가는 ...
# 916  빌런으로 빙의헀다. \r\n\r\n그것도 주인 수를 감금해서 괴롭히다가 주인 공한테...
# 917  나의 네임은 미야 아츠무다. 그리고 난 미야 오사무가 되었다.\n[미야형제/전생/네...
# 918              완성품에 숟가락만 얹어 날로먹는 직업 인챈터의 이야기\r\n\r\n
# 919   아저씨가 집에 돌아왔다. 근데 이상한 걸..아니 존나 예쁜 걸 달고 왔다. 문제는...
#
# [920 rows x 4 columns]

# %%
#print(df[(df['date'] >= 20201214) & (df['date'] <= 20201220) & (df['genre'] == '[BL]')])
import datetime
from pytz import timezone
today = datetime.datetime.now(timezone('Asia/Seoul'))
start = today - datetime.timedelta(days = 1-1)
t = int(today.strftime('%Y%m%d')) 
s = int(start.strftime('%Y%m%d')) 
print(t)
print(s)
print(df[(df['date'] >= s) & (df['date'] <= t) & (df['genre'].isin(['[판타지]', '[패러디]', '[로맨스판타지]', '[팬픽]']) ) ] )
date = datetime.datetime.now(timezone('Asia/Seoul')).strftime('%Y%m%d')
# Out:
# 20210204
# 20210204
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d9c39687f96d> in <module>
#       8 print(t)
#       9 print(s)
# ---> 10 print(df[(df['date'] >= s) & (df['date'] <= t) & (df['genre'].isin(['[판타지]', '[패러디]', '[로맨스판타지]', '[팬픽]']) ) ] )
#      11 date = datetime.datetime.now(timezone('Asia/Seoul')).strftime('%Y%m%d')
#
# NameError: name 'df' is not defined

# %%
def fillter(df, term, genres): 
    result = pd.DataFrame(columns=['date', 'genre', 'title', 'intro'])
    today = datetime.datetime.now(timezone('Asia/Seoul'))
    start = today - datetime.timedelta(days = term-1)
    t = int(today.strftime('%Y%m%d')) 
    s = int(start.strftime('%Y%m%d')) 
    return df[(s <= df['date']) & (df['date'] <= t) & (df['genre'].isin(genres))]

gen_list = ['[판타지]', '[패러디]', '[로맨스판타지]', '[팬픽]'] 
fillterd_date = date_fillter(7, df) #날짜로 필터링하기
print(fillterd_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-96c04e46310f> in <module>
#       8
#       9 gen_list = ['[판타지]', '[패러디]', '[로맨스판타지]', '[팬픽]']
# ---> 10 fillterd_date = date_fillter(7, df) #날짜로 필터링하기
#      11 print(fillterd_date)
#
# NameError: name 'date_fillter' is not defined

# %%
#일수 넣으면 해당 기간에 걸친 날짜 반환
# 7일 넣으면 지난 일주일 날짜 반환 
import boto3
import pandas as pd
from io import StringIO
import time, datetime
from pytz import timezone
def read_data_from_s3(db_name):
    
    f = open("/home/ubuntu/Downloads/rootkey.txt", 'r')
    rootkey = f.read().splitlines()
    f.close()
    
    aws_id = rootkey[0]
    aws_secret = rootkey[1]
    
    bucket_name = 'web-novel-db'
    object_key = db_name
    client = boto3.client('s3',aws_access_key_id= aws_id, aws_secret_access_key=aws_secret)
    csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')
    return pd.read_csv(StringIO(csv_string))

data_frame = read_data_from_s3('joara-tobe.csv')

def date_fillter(term, df):
    result = pd.DataFrame(columns=['date', 'genre', 'title', 'intro'])
    for day in range(0, term):
        d = datetime.datetime.now(timezone('Asia/Seoul')) - datetime.timedelta(days = day)
        date = d.strftime('%Y%m%d')
        print(date)
        this = df.query('date ==' + date)
        result = pd.concat([result, this])
    return result
fillterd_date = date_fillter(2, data_frame)
print(fillterd_date)
# Out:
# 20210204
# 20210203
#          date     genre                               title  \
# 900  20210204      [BL]                       라스트 커튼콜 <74편>
# 901  20210204     [판타지]                  천재 파티셰가 되었다 <124편>
# 902  20210204  [로맨스판타지]              얼떨결에 집착광공이 되어버렸다 <28편>
# 903  20210204  [로맨스판타지]          가짜 남동생의 집착이 나를 향할 때  <22편>
# 904  20210204  [로맨스판타지]                   흑막명가 막내 아가님 <22편>
# 905  20210204  [로맨스판타지]            새 가문과 약혼자를 맞이하겠습니다 <31편>
# 906  20210204  [로맨스판타지]          길드마스터는 게임 속에서만으로 충.. <27편>
# 907  20210204  [로맨스판타지]             성녀가 못생긴 건 처음 봅니까? <68편>
# 908  20210204      [BL]                        파도의 숨  <23편>
# 909  20210204      [BL]                     세이프티 플레이스 <20편>
# 910  20210204      [BL]      원 히트(Heat) 원더 ( 完 ~2/6 ) <56편>
# 911  20210204      [BL]                       눈물 젖은 벽 <46편>
# 912  20210204     [판타지]                      재벌생활기록부 <350편>
# 913  20210204  [로맨스판타지]               시한부 공녀는 살길을 찾는다 <24편>
# 914  20210204     [패러디]  (fate / fgo)룰렛은 너의 지옥을 가.. <1100편>
# 915  20210204     [패러디]                    [원피스] 마르셀라 <25편>
# 916  20210204      [BL]                        빌런의 반란 <25편>
# 917  20210204     [패러디]                [하이큐] 내가 사는 이유 <67편>
# 918  20210204     [패러디]                     [던만추] 인챈터 <41편>
# 919  20210204     [패러디]                   [주술회전] 실화일까 <39편>
# 880  20210203  [로맨스판타지]                    이혼 후의 해피엔딩 <22편>
# 881  20210203      [BL]                       트루러브/컨셉 <31편>
# 882  20210203      [BL]                          서털구털 <21편>
# 883  20210203     [패러디]                [인소의 법칙] 돈을 벌자 <20편>
# 884  20210203      [BL]                       라스트 커튼콜 <74편>
# 885  20210203     [패러디]                  [이누야샤] 미완성게임 <45편>
# 886  20210203      [역사]             상태창 소환 삼국지 : 도영전 <260편>
# 887  20210203     [패러디]            [해리포터] 위대한 사랑에 대하여 <40편>
# 888  20210203     [판타지]                   용돈이 계속 늘어! <250편>
# 889  20210203  [로맨스판타지]            황후가 아니라 마탑주가 되겠습니다 <22편>
# 890  20210203  [로맨스판타지]              얼떨결에 집착광공이 되어버렸다 <26편>
# 891  20210203  [로맨스판타지]            새 가문과 약혼자를 맞이하겠습니다 <31편>
# 892  20210203  [로맨스판타지]                   그 꽃밭은 개를 문다 <33편>
# 893  20210203  [로맨스판타지]             제 유서는 그런 뜻이 아니었는데 <30편>
# 894  20210203     [판타지]                  돌아온 요리고 고인물 <241편>
# 895  20210203     [판타지]                    S2급 결혼 헌터 <139편>
# 896  20210203     [패러디]                [인소의 법칙]한 끗 차이 <34편>
# 897  20210203      [퓨전]             망나니 7황자는 꿀 빨고 싶다 <222편>
# 898  20210203  [로맨스판타지]           본의 아니게 랭킹 1위가 되어버렸다 <23편>
# 899  20210203  [로맨스판타지]              소설 속 멍청한 조연이 되었다 <24편>
#
#                                                  intro
# 900  연기물/빙의물/(짭)근친\r\n\r\n공: 민해우(25) 배우공, 연하공, 짝사랑공...
# 901  세계 최고의 제과제빵 명문대학 '르 에뚜왈 블루'의 신입생 강준서.\r\n어느날 갑...
# 902  BL소설 속 병약수와 똑같은 희귀 병을 앓다 죽길 3회차.\r\n\r\n더는 이렇게...
# 903  죽은 남동생과 비슷한 소년을 데려와 학대하는 미치광이 악녀로 빙의했다. 하필이면 가...
# 904  소설 속 인물로 환생했다.\r\n\r\n그것도 소설 최대 흑막 중 하나인 에이메인 ...
# 905  “나가거라, 너는 내 딸이 아니다. 능력이 없는 자에게 베노마인의 이름을 허락할 수...
# 906  게임이 현실이 되면, 나는 신이다.\r\n[여주현판/먼치킨/공성전/길드마스터/액션/...
# 907  #빙의회귀아님#능력여주#로맨스는먹는건가\r\n\r\n세계 최고의 실력을 가진 치료사...
# 908  [키잡물, 육아물, 나이차이, 달달물, 쌍방구원물, 현대물, 인외존재 ] \r\n\...
# 909  [ 스토커공 / 집착공 / 뻔뻔공 / 까칠수 / 결벽증수 / 미인수 ]\r\n\r\...
# 910  #오메가버스 #힛싸파트너 #억제제부작용 #히트 #노팅 #선히트후연애 #이웃사촌이공 ...
# 911  매일 밤, 누군가 내 귓가에서 울음소리를 낸다.\r\n\r\n(단정수/미인수/능력수...
# 912                       회귀한 재벌 2세의 버킷 리스트! 인생은 달곰하게~
# 913  스무 살 전에 죽을 운명을 안고 태어났다. 그리고 나는 정말 스무 살 전에 죽었다....
# 914  표지의 룰렛이 이 소설의 시작이자 끝이자 만악의 근원입니다\r\n\r\n유열러 아닙...
# 915  돈키호테 도플라밍고의 쌍둥이 형.\n게으르게 살고 싶어서 누구보다 열심히 살아가는 ...
# 916  빌런으로 빙의헀다. \r\n\r\n그것도 주인 수를 감금해서 괴롭히다가 주인 공한테...
# 917  나의 네임은 미야 아츠무다. 그리고 난 미야 오사무가 되었다.\n[미야형제/전생/네...
# 918              완성품에 숟가락만 얹어 날로먹는 직업 인챈터의 이야기\r\n\r\n
# 919   아저씨가 집에 돌아왔다. 근데 이상한 걸..아니 존나 예쁜 걸 달고 왔다. 문제는...
# 880  사교계에서 가장 아름다운 영애. 릴리 헤드윅.\r\n\r\n그녀는 불운한 결혼생활을...
# 881  망돌 매니저인 내가 재벌 3세의 스폰서 제안을 받았는데 10년차 인기아이돌인 후배가...
# 882  #동양판타지 #차원이동 #초반혐관 #성관계로 요력충전 #특별한 물건을 가진 공 \r...
# 883  인소의 법칙 속으로 트립했다. 문제가 하나 있다면, 내게 돈이 없다는 것이었다. 그...
# 884  연기물/빙의물/(짭)근친\r\n\r\n공: 민해우(25) 배우공, 연하공, 짝사랑공...
# 885  큭-\r\n점점 막혀오는 숨에 내 목을 죄고 있는 나라쿠의 손을 잡았다.\r\n\r...
# 886  [시스템물] [사이다]\r\n서주목 도겸의 장자 도영으로 회귀했지만, 애석하게도 도...
# 887                                똑똑하지만 우울한 해리포터의 이야기
# 888                                  누가 나한테 자꾸 용돈을 준다.
# 889  가문의 명예를 위해 기꺼이 황태자비가 되었다.\r\n황후의 자리까지 올라가려, 황태...
# 890  BL소설 속 병약수와 똑같은 희귀 병을 앓다 죽길 3회차.\r\n\r\n더는 이렇게...
# 891  “나가거라, 너는 내 딸이 아니다. 능력이 없는 자에게 베노마인의 이름을 허락할 수...
# 892  [직진녀+능글녀X철벽남 → 철벽녀X직진남]\r\n\r\n\r\n“내가 아주 예뻐 죽...
# 893  #마수 남주 #시한부 여주 #비틀린 남주 #계략 남주 #해맑은 여주 #구원자 여주\...
# 894  그토록 꿈꾸었으나 눈앞에서 놓쳤던 진짜 쉐프가 될 기회.\r\n한 번은 놓쳤던 그 ...
# 895                                          아내가 너무 예쁨
# 896  여기가 소설이라고 알 수 있었던 이유는 엄마의 죽음 때문이었다.\r\n\r\n\r\...
# 897  소멸을 각오했더니, 이미 죽어버린 망나니의 육체에 갇혔다.\r\n\r\n제국의 황자...
# 898  #여주현판 #먼치킨 #랭킹1위여주 #힘숨찐 #소꿉친구 #너무약한S급헌터들 #천족남주...
# 899  #정치인의사생아가 #공작가의양녀로 #악녀는 #벌을받고 #소설속그녀는멍청해도 #난똑똑...

# %%
def genre_fillter(genres, df):
    result = pd.DataFrame(columns=['date', 'genre', 'title', 'intro'])
    for genre in genres:
        gen = '['+genre+']'
        this = df.query('genre == "' + gen + '"')
        result = pd.concat([result, this])
    return result

#gen_list = ['판타지', '패러디', 'BL', '팬픽']
#print(genre_fillter(gen_list, fillterd_date))

print(termdata & genredata)
# Out:
#         date  genre                        title  \
# 18  20201220  [패러디]  [Fate] 사죠 마나카가 되었습니다. <91편>
# 10  20201220   [BL]      헤비 레인(Heavy Rain) <33편>
# 11  20201220   [BL]       새앙쥐는 늑대를 사랑하고 있다 <95편>
# 13  20201220   [BL]               돌아와서 말하기 <24편>
# 14  20201220   [BL]             [完] 향기의 언어 <52편>
# 16  20201220   [BL]                뜬장 위의 개 <26편>
# 17  20201220   [BL]           더블 빅소세지 샌드위치 <22편>
# 2   20201219   [BL]              슬로우 러브 어택 <21편>
# 4   20201219   [BL]                   호구조사 <21편>
# 5   20201219   [BL]           테소로 오브 더 가이드 <67편>
# 7   20201219   [BL]              영웅은 죽고 싶다 <53편>
#
#                                                 intro
# 18  1991년에 일어난 도쿄 1차 성배전쟁. 그 성배전쟁의 마스터 중 한 명이자 근원연...
# 10  초반무심공이 체념수의 도망에 집착후회공이 되는 이야기\r\n\r\n*강압적 관계 등...
# 11  시궁창 새앙쥐에게는 보물이 하나 있다.\r\n하수구 구정물에서도 선명하게 빛나는 노...
# 13  *오메가버스, 현대물, 회귀물\r\n*재벌공, 강공, 후회공, 존댓말공x미인수, 자...
# 14  * BL / 오메가버스 / 현대물\r\n* 연하공/ 미인공 / 다정공 / 집착공 /...
# 16  #오메가버스 #현대물 #달달물 지향 #(과거)약피폐 #나이차이 #쌍방구원\r\n\r...
# 17  #다공일수 #이공일수 #3P #쓰리썸 #다같살 #뇌맑수 #직진공 #원홀투스틱 #왕햄...
# 2   [아이돌물 / 연하공 미인공 짝사랑공 집착공 수한정다정공 / 연상수 다정수 능력수 ...
# 4   불도저연하공 x 한입거리눈새수\r\n무섭게 생긴 후배가 자꾸 맛있는 걸 쥐여 준다....
# 5   *그 가이드 세계에서 일반인으로 살아남기.\r\n\r\n백시진은 생명의 은인인 함건...
# 7   학원물, 청게물, 재회물, 회귀(타임워프), 성장물, 치유물, 잔잔물, SF요소\r...

# %%
def read_data_from_s3(db_name):
    aws_id = 'AKIAIPHKZIJNFNELEDFA'
    aws_secret = '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'
    bucket_name = 'web-novel-db'
    object_key = db_name
    client = boto3.client('s3',aws_access_key_id= aws_id, aws_secret_access_key=aws_secret)
    csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')
    return pd.read_csv(StringIO(csv_string))

def date_fillter(term, df):
    result = pd.DataFrame(columns=['date', 'genre', 'title', 'intro'])
    for day in range(0, term):
        d = datetime.datetime.now(timezone('Asia/Seoul')) - datetime.timedelta(days = day)
        date = d.strftime('%Y%m%d')
        print(date)
        this = df.query('date ==' + date)
        result = pd.concat([result, this])
    return result

def genre_fillter(genres, df):
    result = pd.DataFrame(columns=['date', 'genre', 'title', 'intro'])
    for genre in genres:
        gen = '['+genre+']'
        this = df.query('genre == "' + gen + '"')
        result = pd.concat([result, this])
    return result

# %%
df = data_frame

a = df[(s <= df['date']) & (df['date'] <= t) & (df['genre'].isin(['[판타지]', '[패러디]', '[로맨스판타지]', '[팬픽]'] ))]
print(a)
# Out:
#          date     genre                               title  \
# 901  20210204     [판타지]                  천재 파티셰가 되었다 <124편>
# 902  20210204  [로맨스판타지]              얼떨결에 집착광공이 되어버렸다 <28편>
# 903  20210204  [로맨스판타지]          가짜 남동생의 집착이 나를 향할 때  <22편>
# 904  20210204  [로맨스판타지]                   흑막명가 막내 아가님 <22편>
# 905  20210204  [로맨스판타지]            새 가문과 약혼자를 맞이하겠습니다 <31편>
# 906  20210204  [로맨스판타지]          길드마스터는 게임 속에서만으로 충.. <27편>
# 907  20210204  [로맨스판타지]             성녀가 못생긴 건 처음 봅니까? <68편>
# 912  20210204     [판타지]                      재벌생활기록부 <350편>
# 913  20210204  [로맨스판타지]               시한부 공녀는 살길을 찾는다 <24편>
# 914  20210204     [패러디]  (fate / fgo)룰렛은 너의 지옥을 가.. <1100편>
# 915  20210204     [패러디]                    [원피스] 마르셀라 <25편>
# 917  20210204     [패러디]                [하이큐] 내가 사는 이유 <67편>
# 918  20210204     [패러디]                     [던만추] 인챈터 <41편>
# 919  20210204     [패러디]                   [주술회전] 실화일까 <39편>
#
#                                                  intro
# 901  세계 최고의 제과제빵 명문대학 '르 에뚜왈 블루'의 신입생 강준서.\r\n어느날 갑...
# 902  BL소설 속 병약수와 똑같은 희귀 병을 앓다 죽길 3회차.\r\n\r\n더는 이렇게...
# 903  죽은 남동생과 비슷한 소년을 데려와 학대하는 미치광이 악녀로 빙의했다. 하필이면 가...
# 904  소설 속 인물로 환생했다.\r\n\r\n그것도 소설 최대 흑막 중 하나인 에이메인 ...
# 905  “나가거라, 너는 내 딸이 아니다. 능력이 없는 자에게 베노마인의 이름을 허락할 수...
# 906  게임이 현실이 되면, 나는 신이다.\r\n[여주현판/먼치킨/공성전/길드마스터/액션/...
# 907  #빙의회귀아님#능력여주#로맨스는먹는건가\r\n\r\n세계 최고의 실력을 가진 치료사...
# 912                       회귀한 재벌 2세의 버킷 리스트! 인생은 달곰하게~
# 913  스무 살 전에 죽을 운명을 안고 태어났다. 그리고 나는 정말 스무 살 전에 죽었다....
# 914  표지의 룰렛이 이 소설의 시작이자 끝이자 만악의 근원입니다\r\n\r\n유열러 아닙...
# 915  돈키호테 도플라밍고의 쌍둥이 형.\n게으르게 살고 싶어서 누구보다 열심히 살아가는 ...
# 917  나의 네임은 미야 아츠무다. 그리고 난 미야 오사무가 되었다.\n[미야형제/전생/네...
# 918              완성품에 숟가락만 얹어 날로먹는 직업 인챈터의 이야기\r\n\r\n
# 919   아저씨가 집에 돌아왔다. 근데 이상한 걸..아니 존나 예쁜 걸 달고 왔다. 문제는...

# %%
from konlpy.tag import Twitter
from collections import Counter

import re





def get_tags(data, ntags=50): 
    hangul = re.compile('[^ a-zA-Z0-9ㄱ-ㅣ가-힣]+') 

    txt = ''

    data = data.title.values.tolist() + data.intro.tolist()
    
    for nov in data:
            txt = txt + ' ' + nov
    
    cleaned_text = hangul.sub(' ', txt)
    spliter = Twitter()
    nouns = spliter.nouns(cleaned_text)
    nouns = [n for n in nouns if len(n) > 1] #한글자 단어 삭제 
    count = Counter(nouns)
    return_dict = {}

    #return_dict = {n, c in cont.most_common(ntags) if n not in ['표지', '소설', '그녀', '무료', '연재']}
    for n, c in count.most_common(ntags):
        #if n == '표지' or n == '소설':
        if n not in ['표지', '소설', '여주', '그녀', '사람', '연재', '무료', '신작']:
            return_dict[n] = c
    return return_dict

get_tags(a, ntags=50)
# Out:
# /home/ubuntu/novel/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# {'남동생': 4,
#  '능력': 4,
#  '가문': 3,
#  '룰렛': 3,
#  '엔딩': 3,
#  '그것': 3,
#  '귀족': 3,
#  '이자': 3,
#  '회귀': 3,
#  '사랑': 3,
#  '설정': 3,
#  '집착': 2,
#  '가짜': 2,
#  '흑막': 2,
#  '약혼자': 2,
#  '길드': 2,
#  '마스터': 2,
#  '게임': 2,
#  '성녀': 2,
#  '재벌': 2,
#  '이유': 2,
#  '세계': 2,
#  '최고': 2,
#  '갑자기': 2,
#  '병약': 2,
#  '숟가락': 2,
#  '이제': 2,
#  '빙의': 2,
#  '시점': 2,
#  '위해': 2,
#  '주의': 2,
#  '에이': 2,
#  '메인': 2,
#  '운명': 2,
#  '별장': 2,
#  '마인': 2,
#  '스페이스': 2,
#  '선전': 2,
#  '지금': 2,
#  '상황': 2,
#  '저주': 2,
#  '청년': 2,
#  '이야기': 2,
#  '스무': 2,
#  '작품': 2,
#  '해당': 2}

# %%
def filtering(genres, term,  db_name):
    
    df = read_data_from_s3(db_name)
    print(df)
    today = datetime.datetime.now(timezone('Asia/Seoul'))
    start = today - datetime.timedelta(days = term-1)
    end_day = int(today.strftime('%Y%m%d')) 
    start_day = int(start.strftime('%Y%m%d')) 
    
    return df[(start_day <= df['date']) & (df['date'] <= end_day) & (df['genre'].isin(genres))]

genres = ['[로판]', '[로맨스]', '[BL]', '[GL]', '[판타지]', '[무협]', '[라이트노벨]', '[추리]', '[팬픽]', '[패러디]', '[문학]']

web = filtering(genres, 1, 'tocsoda-tobe-web.csv')
free = filtering(genres, 1, 'tocsoda-tobe-free.csv')
filtered = pd.concat([web, free])
# Out:
#          date  genre              title  \
# 0    20201220  [판타지]      게임 폐인의 리셋 라이프
# 1    20201220  [판타지]     전업 힐러는 점점 강해진다
# 2    20201220  [판타지]           살인마의 인터뷰
# 3    20201220  [판타지]          0살부터 슈퍼스타
# 4    20201220  [판타지]   기레기와 함께하는 연예계 생활
# ..        ...    ...                ...
# 935  20210204  [판타지]           배우로서 살겠다
# 936  20210204   [로판]  무협 최고 악당을 길들여 버렸다
# 937  20210204  [판타지]      백작가의 망나니가 되었다
# 938  20210204  [판타지]         내 스킬은 천마신공
# 939  20210204  [판타지]          0살부터 슈퍼스타
#
#                                                intro
# 0            전국수석, 패셔니스타, 톱 모델! 이제 더 이상 꿈이 아니라 현실이다!
# 1        대충 이세계에 떨어졌지만 어찌어찌 좋은 사람을 만나 자리잡고 살아간다는 내용.
# 2                    살인마의 시선으로 범인 잡는 형사 박하준의 성장 스토리!
# 3              미친 미모! 미친 연기! 사람들을 사로잡는 그는 0살부터 슈퍼스타!
# 4                             불운 연예인, ‘운빨’로 다시 시작하다.
# ..                                               ...
# 935                             연기에 미친 놈, 배우로서 살아가다!
# 936                            이런 이야기…… 원작에선 없었는데……?
# 937        눈을 떠보니 소설 속이었다. 그것도 망나니로 유명한 백작가 도련님 몸으로.
# 938  죽음의 문턱에서 천마가 주는 기회를 받아 24년 전, 16살의 어린 나이로 회귀한다.
# 939            미친 미모! 미친 연기! 사람들을 사로잡는 그는 0살부터 슈퍼스타!
#
# [940 rows x 4 columns]
#          date  genre                        title  \
# 0    20201220  [패러디]              [원피스] 앨리스의 잡화상점
# 1    20201220  [패러디]            [하이큐] 치즈루 씨의 수난일기
# 2    20201220   [팬픽]         [원피스] 내 집이 워프게이트가 됐다
# 3    20201220  [패러디]                     [하이큐] 비상
# 4    20201220  [패러디]    [패러디/은혼]이 바보 남편아, 그만 좀 해!
# ..        ...    ...                          ...
# 935  20210204  [패러디]  [하이큐/BL] 　Blue Age (푸르른 시대)
# 936  20210204  [패러디]    [해리포터] Get lost in a maze
# 937  20210204  [패러디]                   [원피스]라디오스타
# 938  20210204  [패러디]              [해리포터] 그녀는 해리에요
# 939  20210204  [패러디]             [하이큐] 건넛집 유카리씨!!
#
#                                           intro
# 0                              앨리스의 잡화상점과 그 손님들
# 1                 *시라토리자와 테니스 부 오이카와 치즈루 씨의 이야기
# 2        원피스 패러디 / 원작 대파괴 / 캐붕 다수 / 표지 커미션: 듀부님
# 3              조금 이르게 핀 벚꽃이 바람에 흩날렸다. 완연한 봄이었다.
# 4    발정난 토끼같은 내 연하 남편때문에 몸이 남아나질 않는다! 어떤 의미로든!!
# ..                                          ...
# 935                    세이죠 전국 우승 소설입니다 <(030)>♡
# 936               소프트 BL/ 해리포터 패러디 레귤러스 주인공입니다.
# 937                밤 12시. 전보벌레에서 라디오가 나오기 시작했다.
# 938                                 해리포터가 여자라면?
# 939     -이것은 괜히 수상쩍은 건넛집 유카리씨와 배구부원들의 일상 이야기이다.
#
# [940 rows x 4 columns]

# %%
def get_weeks_data(term):
    joara = read_data_from_s3('joara-tobe.csv')
    bookpal = read_data_from_s3('bookpal-tobe.csv')
    tocsoda_web = read_data_from_s3('tocsoda-tobe-web.csv')
    tocsoda_free = read_data_from_s3('tocsoda-tobe-free.csv')

    novel = pd.concat([joara,bookpal, tocsoda_web, tocsoda_free])

    today = datetime.datetime.now(timezone('Asia/Seoul'))
    start = today - datetime.timedelta(days = term-1) 
    end_day = int(today.strftime('%Y%m%d')) 
    start_day = int(start.strftime('%Y%m%d')) 
    return novel[(start_day <= novel['date']) & (novel['date'] <= end_day)]

filtered = get_weeks_data(7); 
top_ten = get_tags(filtered, 10)
top_keys = top_ten.keys()
print(top_keys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ff661312de4c> in <module>
#      14
#      15 filtered = get_weeks_data(7);
# ---> 16 top_ten = get_tags(filtered, 10)
#      17 top_keys = top_ten.keys()
#      18 print(top_keys)
#
# <ipython-input-20-d30a80356b8f> in get_tags(data, ntags)
#      11
#      12     for nov in data:
# ---> 13             txt = txt + ' ' + nov
#      14
#      15     cleaned_text = hangul.sub(' ', txt)
#
# TypeError: must be str, not float
