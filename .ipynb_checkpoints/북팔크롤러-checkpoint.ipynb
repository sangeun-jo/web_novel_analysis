# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import os
import re
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "web_novel_analysis.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
import django
django.setup()
from bookpal.models import TodayBest

# %%
now = time.localtime()

hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') 

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless')
#driver = webdriver.Chrome('D:/chromedriver.exe', options=chrome_options)
driver = webdriver.Chrome('D:/chromedriver.exe')

driver.get('https://novel.bookpal.co.kr/novel@best?depth=list_search')
time.sleep(180)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
#book_list = soup.find('ul', class_='list-text').find_all('a')
print(soup)
#print(book_list)

date = str(now.tm_year)+str(now.tm_mon)+str(now.tm_mday)

titles = soup.select_one('#list_items').find_all('div', class_='title') #제목 리스트 
gks = soup.find_all('p', class_='info m-t-m clear-f') #키워드, 장르 리스트 
introes = data.find_all('p', class_='summary') #소개글 리스트


for tit, gk, intr in zip(title, gks, introes):
    #try:
    title = tit.strip()
    genre = re.search(r'\[(.*?)\]', gk.text).group() 
    intro = gk.text.replace(genre, '') + ' ' + intr.text
    #except:
    #    title = 'failed'
    #    genre = ''
    #    intro = ''
    TodayBest(date=date, genre=genre, title=title, intro=intro).save()
driver.close()
# Out:
# <html lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="IE_RM_OFF"/>
# <title>북팔웹소설</title>
# <meta content="[북팔 웹소설] BookPal" name="author"/>
# <!--<meta name="keywords" content="북팔,Bookpal,bookpal,로맨스소설,웹소설,책,무료책,성인소설,전자책,ebook">-->
# <meta content="북팔웹소설" name="title"/>
# <meta content="스토리가 빛나는 순간 - 내일의 히트 콘텐츠가 오늘 북팔에서 연재됩니다." name="description"/>
# <meta content="스토리가 빛나는 순간 - 내일의 히트 콘텐츠가 오늘 북팔에서 연재됩니다." property="og:description"/>
# <meta content="북팔웹소설" property="og:title"/>
# <meta content="https://novel.bookpal.co.kr/_statics/novel/common/og_image1.png" property="og:image"/>
# <!-- <meta property="og:image" content="https://novel.bookpal.co.kr/_statics/novel/common/og_image.png"> -->
# <meta content="@bookpal" name="twitter:site"/>
# <meta content="북팔웹소설" name="twitter:title"/>
# ...

# %%
#titles[0].text.strip() 개별 제목 얻는 법


#키워드, 장르 구분하기

g_and_k = g_and_k[0]
genre = re.search(r'\[(.*?)\]' , genre).group() #[]장르
g_and_k = g_and_k.replace(genre, '')

print(genre)


intro = introes[0]
intro = g_and_k + ' ' + intro.text
print(intro)


'''
<ul class="list list-default list-m" id="list_items">
    <li> 
        <a class="clear-f" href="https://novel.bookpal.co.kr/view/55416" title="이제 그만하자"> 
            <div class="con-cover"> 
                <span class="ic-mark-bl "></span> 
                <span class="ic-mnpoly"></span> 
                <img alt="표지" src="https://image.bookpal.co.kr/img_view.php?bid=55416&amp;thumb=1&amp;img_type=1350&amp;time=2020052304&amp;key=87&amp;default=1"/> </div> 
                <div class="con-info"> <div class="con-views"> 
                <span class="date">2020.05.23</span> 
            </div> 
            <div class="title"> 
                <span class="ic-book-up"></span>                  이제 그만하자               
            </div> 
            <div class="writer">                                          번쩍번찍 물망초               </div> 
            <p class="info m-t-m clear-f">                     · [현대BL] 학원 | 연상연하 | 원나잇 | 후회 | 삼각관계                         
            <br/> · 신작 |               연재 |         총 6화        | 
            <span class="free">6화 무료</span> </p> 
            <p class="summary">                 · 학원에서 만난 제자 구진혁에게 동정심으로 시작된 사랑에 빠진 학원 보조 선생님 선아인의 이야기. 제자의 외로움을 자신이 채워줄 수 있을 거라는 자신감으로 시작된 연애였지만 구진혁의 잦은 바람으로 상처를 받아 버려지지만 애증으로 구진혁의 옆에 있는 선아인. 자신도 자신이 호구라는 것을 알지만 구진혁에 대한 맘을 사랑으로 세뇌시키는 선아인.               </p>


for book in book_list:
    try:
        title = book['title'] #책 제목
        url = book['href'] #상세 정보를 위해 링크로 이동 
        driver.get(url)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        _genre = soup.find('p', class_='info')
        genre = hangul.sub('', str(re.search(r'\[(.*?)\]' , _genre.text).group()))
        intro = soup.find('div', class_='con-summary').p.text 
    except:
        title = 'failed'
        genre = ''
        intro = url
    TodayBest(date=date, genre=genre, title=title, intro=intro).save()

driver.close()
'''
# Out:
# [현대BL]
#                    · 학원에서 만난 제자 구진혁에게 동정심으로 시작된 사랑에 빠진 학원 보조 선생님 선아인의 이야기. 제자의 외로움을 자신이 채워줄 수 있을 거라는 자신감으로 시작된 연애였지만 구진혁의 잦은 바람으로 상처를 받아 버려지지만 애증으로 구진혁의 옆에 있는 선아인. 자신도 자신이 호구라는 것을 알지만 구진혁에 대한 맘을 사랑으로 세뇌시키는 선아인.
# ...

# %%
#hrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument('headless')
#driver = webdriver.Chrome('D:/chromedriver.exe', options=chrome_options)
driver = webdriver.Chrome('D:/chromedriver.exe')

driver.get('https://novel.bookpal.co.kr/novel@best?depth=list_search')
time.sleep(10)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
#book_list = soup.find('ul', class_='list-text').find_all('a')
print(soup)
# Out:
# <html lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="IE_RM_OFF"/>
# <title>북팔웹소설</title>
# <meta content="[북팔 웹소설] BookPal" name="author"/>
# <!--<meta name="keywords" content="북팔,Bookpal,bookpal,로맨스소설,웹소설,책,무료책,성인소설,전자책,ebook">-->
# <meta content="북팔웹소설" name="title"/>
# <meta content="스토리가 빛나는 순간 - 내일의 히트 콘텐츠가 오늘 북팔에서 연재됩니다." name="description"/>
# <meta content="스토리가 빛나는 순간 - 내일의 히트 콘텐츠가 오늘 북팔에서 연재됩니다." property="og:description"/>
# <meta content="북팔웹소설" property="og:title"/>
# <meta content="https://novel.bookpal.co.kr/_statics/novel/common/og_image1.png" property="og:image"/>
# <!-- <meta property="og:image" content="https://novel.bookpal.co.kr/_statics/novel/common/og_image.png"> -->
# <meta content="@bookpal" name="twitter:site"/>
# <meta content="북팔웹소설" name="twitter:title"/>
# ...
