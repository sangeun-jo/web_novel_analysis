# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "web_novel_analysis.settings")
import django
django.setup()

from wordcloud import WordCloud
import matplotlib.pyplot as plt
from web_novel_analysis.base import get_tags
from web_novel_analysis.base import wordcloud

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import re
import time

# %%
def bookpal_comment(url):
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('headless')
    driver = webdriver.Chrome('D:/chromedriver.exe', options=chrome_options)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    commentList = []
    cnt = 1
    
    #북팔은 댓글 첫 페이지 입력하라고 하기 
    while True:  
        driver.get(url +'?page=' + str(cnt))
        cnt = cnt + 1
        time.sleep(0.3)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        comments = soup.find_all('div', class_='con-comm')
        if comments:
            for comment in comments:
                commentList.append(comment.text.strip())
        else:
            break; 
    driver.close()
    return commentList

# %%
print(commentList)
# Out:
# ['49화\n                        초딩재오 ㅋㅋㅋ 다행입니다^^', '49화\n                        솔직히 승재도 왕짜증!!\n어쨌든 해결되서 속이 시원하네요.', '49화\nㅋㅋㅋ 재오어린이네~~\n잘 읽었습니다', '48화\n이런 라이벌 등장이네...\n재오 우짜노...ㅋㅋ', '49화\n잘보고갑니다‥', '49화\n                        드디어 풀렸네 드디어ㅎㅎㅎ', '49화\n                        드디어 오해가 풀렸네요..참 힘든시간이였어요 보는 사람도요^^', '48화\n                        아무래도 재오는 바보임에 틀림없어', '48화\n재오가..너무..다른방법을 선택하지.ㅠㅠ 너무 하긴 한것같아요.', '48화\n                        갈아타여', '48화\n                        이거이거...이 상태로 오래갈 각이구만..', '48화\n고생한 보람이 없네.재오만 고생', '48화\n                        아니 승재 델다가 이경이한테 얘기하게하고 수연이는 딴사람시켜서 밟아버림되는걸..구지 그렇게해야했나ㅡㅡ', '48화\n                        재오야...진짜 고생한 보람도 없이ㅠㅠ', '48화\n                        재오야ㅠㅠㅠ', '47화\n아직 오해가 안풀렸는데ㅜㅜ\n잘 읽었습니다', '47화\n                        너무꼰다ㅠ', '47화\n                        의사랑잘되길', '47화\n                        속상하다ㅠㅠ', '47화\n                        제3의 인물 등장인가요?', '47화\n                        못봤네 오해가  풀릴려면 길이 험 하겠네', '47화\n                        앗 잘못쳤다 이경이가 아니라 이경이를..좋아했던 남자', '47화\n엇...ㅠㅠ 새로운 서브남주 등장??', '47화\n                        윤한결..중학굔가 고등학굔가..이경이 좋아했다는 남자 아닌가요?', '47화\n                        윤한결은 누구징', '47화\n의사는또 누구신가? 잘보고갑니다‥ 숨도 안쉬고 읽어버렸어요‥', '47화\n                        에휴...이런일이 있었네', '46화\n                        1화부터 정주행했어요~~중반부터 몰입도 너무 좋아서 쉬지 않고 봤네요.\n그래서 이경이는 그 영상을 본건가요 못본건가요.............', '46화\n                        드디어 사이다네요~~~\n작가님.. 잘 읽고 있습니다~~^^', '46화\n                        고구마 구간 빨리 지나가길~', '46화\n                        저런들 좋은감정이 있겠냐구..ㅠㅠ', '45화\n                        수연이 그지지배는 ㅡㅡ 하필 내이름도 수연이네요....', '46화\n                        무슨 저런식으로해명을', '46화\nㅠㅠ 정신을 차린 이경이가 제발 봤기를..ㅠㅠ 와 ㅠㅠ 두편씩이나 너무 좋아요. 사이다 시작 되는건가요.ㅋㅋ', '46화\n                        그런데 이경이가 못들었으니 무슨소용이래요 ㅠ', '46화\n이경이 영상을 끝까지 못봐 우째요...ㅜㅜ\n잘 읽었습니다', '46화\n아‥ 드디어‥ 잘보고갑니다‥', '46화\n                        와~~ 재오 대박!!', '44화\n                        그러니까  왜  오해의 함지박을 가지고 있냐고   수습 복잡하게..   아구  ....', '44화\n                        이래서  소통이...', '34화\n                        재오가  귀엽네요  ㅋ', '44화\n결국 경찰서가서..허허허 그러게 좀 속시원하게 얘기를 했어야지..ㅜㅜ 답답..ㅠㅠ', '44화\n                        뒤늦게 정주행 했어요^^감사합니다~', '44화\n참 답답한 커플이네요~~~\n잘 읽었습니다', '44화\n                        아이고..얘넨 헤어지는게 나을거같아요..ㅜㅜ', '44화\n맞어 대화좀‥', '44화\n                        제발 대화란 걸 좀 하자ㅠㅠㅠ', '42화\n                        솔직하게 터 놓고 물어 이경아 오해의 소지를 준건 맞는데 난 왜 니가 고구마일까', '43화\n대체 왜 사랑이 집착으로 변하는지....', '43화\n                        둘다 속시원하게 얘길안하니 꼬일대로 꼬여서', '43화\n사이다 기다릴게요', '43화\n                        재호집착 기대합니당', '43화\n재호야 남자에 집착한번 보려줘 ㅠㅠ 가슴이 아프다 이것들아~~', '43화\n가슴이 아프네요....ㅠ', '43화\nㅠㅠ 저런저런..ㅠㅠ 속시원히 대화로 풀어서 오해를 풀었으면..ㅠㅠ', '43화\n                        에후...또 엇갈리네요', '42화\n수현의 집착이라면 정말 끔직 하네요  잘봤어요', '42화\n이렇게 혼자 골골 될빠엔 쿨하게 헤어지자 이경아~~~~ ㅠㅠ', '42화\n                        점점 짧은거같은건 저만그런가요?ㅋㅋㅋ빨리 둘이 좋은거보고싶은데ㅠㅠ맨날 고구마야', '42화\n                        작가님 한 편만 더 올려 주세요', '42화\n                        윽 또 고구마였어', '42화\n이제 슬슬 사이다를..사이다가 먹고싶어요 사이다 주세요!!!', '42화\n언제까지 고구마인가요? 답답 ㅜㅜ', '42화\n                        아휴...이제 그만 좀 하자', '41화\n수연이 심정 이해 가네 조금만 대화를 한다면 좋아질 텐데   아쉽네', '38화\n수연이가 그날일을 오해고 욕심이였다며 알려줬으면', '33화\n행복하길', '31화\n할아버지 멋있으세요', '41화\n                        승재가 예전처럼 또 수연일 이용하고잇는듯 수연은 재오가아닌 승재를 탐내고', '41화\n사이다가 필요합니다', '41화\n                        수연이 설마 승재랑 붙어먹은거아냐', '41화\n제발 꼭 믿어줘..ㅠㅠ 끝까지!! 재오가 널 두고 그럴애가 아냐', '41화\n                        언제까지 이경이를 괴롭히려고 그러는지\n수연이 참 못됐다\n벌 좀 받아야하겠어요', '41화\n나쁜 수연이...ㅠㅠ', '41화\n잘보고갑니다‥', '41화\n                        작가님 사이다 좀ㅠㅠㅠ', '40화\n재오 오해 만들지 말지', '40화\n                        재오가 말못할사정이 있는게 분명함', '40화\n                        아 왜??  왜서 그러냐구...', '40화\n헐..ㅠㅠ 재오가.왜 거짓말을!!', '40화\n대체 왜!!! ㅠㅠ 혹시 수연이가 나타난건가요?!?!', '40화\n                        이리 끊으시면 ㅠ\n맘아파용', '40화\n                        하나 더 올려줘요ㅠㅠㅠ', '39화\n                        재오는 아직도 20살 그때같은데ㅋㅋㅋ', '39화\n뭔일이 있었기에..ㅠㅠ', '39화\n무슨일을 벌일려고 ㅜㅜ', '39화\n                        재오 너무 귀엽다ㅋㅋ', '38화\n잘보고갑니다‥', '38화\n                        이제 수연이의 만행을 밝힐때가 됐어ㅛ!!!', '38화\n          ...

# %%
print(commentList)
nexturl = soup.find('li', class_='next').a['href']
#commentList = []
# Out:
# ['49화\nㅋㅋㅋ 재오어린이네~~\n잘 읽었습니다', '48화\n이런 라이벌 등장이네...\n재오 우짜노...ㅋㅋ', '49화\n잘보고갑니다‥', '49화\n                        드디어 풀렸네 드디어ㅎㅎㅎ', '49화\n                        드디어 오해가 풀렸네요..참 힘든시간이였어요 보는 사람도요^^', '48화\n                        아무래도 재오는 바보임에 틀림없어', '48화\n재오가..너무..다른방법을 선택하지.ㅠㅠ 너무 하긴 한것같아요.', '48화\n                        갈아타여', '48화\n                        이거이거...이 상태로 오래갈 각이구만..', '48화\n고생한 보람이 없네.재오만 고생']

# %%
print(nexturl)
# Out:
# http://novel.bookpal.co.kr/view%5Ereview/54765?page=6
